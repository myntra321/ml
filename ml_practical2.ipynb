# %%
import pandas as pd

# %%
data=pd.read_csv("temperatures.csv")

# %%
data
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0    29.97  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1    29.12  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2    29.04  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3    29.20  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4    30.67  27.52  23.82   28.30    22.25    30.00    31.33    26.57
# ..     ...    ...    ...     ...      ...      ...      ...      ...
# 112  30.27  27.83  25.37   29.81    25.58    32.58    31.33    27.83
# 113  30.29  28.05  25.08   29.72    24.90    31.82    32.00    27.81
# 114  31.04  28.10  25.67   29.90    25.74    31.68    31.87    28.27
# 115  31.98  30.11  28.01   31.63    28.33    34.57    32.28    30.03
# 116  32.29  29.60  27.18   31.42    27.95    34.13    32.41    29.69
#
# [117 rows x 18 columns]

# %%
x_train=data[["YEAR"]]

# %%
y_train=data[["ANNUAL"]]

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict([[2050]])
# Out:
# C:\Users\91993\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[30.37543142]])

# %%
predicted=model.predict(x_train)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_train,predicted)
# Out:
# 0.10960795229110358

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_train,predicted)
# Out:
# 0.22535284978630418

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train,predicted)
# Out:
# 0.641807891278368

# %%
import matplotlib.pyplot as pl

# %%
pl.scatter(x_train,y_train)

# %%
pl.plot(x_train,y_train)

# %%
pl.plot(x_train,predicted)

# %%
plt.plot(x_train,y_train)
plt.plot(x_train,predicted)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,predicted)

# %%
plt.plot(x_train,y_train)
plt.plot(x_train,predicted)
plt.xlabel("YEAR")
# Out:
# Text(0.5, 0, 'YEAR')

# %%
plt.plot(x_train,y_train)
plt.plot(x_train,predicted)
plt.xlabel("YEAR")
plt.ylabel("Temp")
# Out:
# Text(0, 0.5, 'Temp')

# %%
plt.plot(x_train,y_train)
plt.plot(x_train,predicted)
plt.xlabel("YEAR")
plt.ylabel("Temp")
plt.title("Annual temp record")
# Out:
# Text(0.5, 1.0, 'Annual temp record')
